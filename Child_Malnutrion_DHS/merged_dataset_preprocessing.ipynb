# %% [markdown]
# <a href="https://colab.research.google.com/github/444vj/child-malnutrition-01/blob/main/merged_dataset_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing the required libraries for EDA

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

sns.set()
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
# importing child underweight dataset

mal = pd.read_csv('/content/1. Percentage-of-underweight-children-data.csv')
mal
# Out:
#     Country Name     Continent Country Code  Year  \
# 0        Albania        Europe          ALB  2016
# 1        Algeria        Africa          DZA  2016
# 2         Angola        Africa          AGO  2016
# 3        Armenia        Europe          ARM  2016
# 4     Azerbaijan        Europe          AZE  2016
# ..           ...           ...          ...   ...
# 661      Vanuatu  Asia/Pacific          VUT  2011
# 662      Vietnam  Asia/Pacific          VNM  2011
# 663        Yemen  Asia/Pacific          YEM  2011
# 664       Zambia        Africa          ZMB  2011
# 665     Zimbabwe        Africa          ZWE  2011
#
#      Percentage of Underweight Children
# 0                                  2.05
# 1                                  4.09
# 2                                 19.10
# 3                                  2.60
# 4                                   NaN
# ..                                  ...
# 661                                 NaN
# 662                               11.70
# 663                               39.60
# 664                               14.50
# 665                                9.70
#
# [666 rows x 5 columns]

# %%
# importing women malnutrition dataset

malw = pd.read_csv('/content/2. Prevalence of Underweight among Female Adults (Age Standardized Estimate).csv')
malw
# Out:
#      Country Code  Country Name  Year  Prevelance of Underweight among Adults
# 0             NRU         Nauru  2016                                     0.3
# 1             TON         Tonga  2016                                     0.4
# 2             COK  Cook Islands  2016                                     0.4
# 3             WSM         Samoa  2016                                     0.5
# 4             TUV        Tuvalu  2016                                     0.6
# ...           ...           ...   ...                                     ...
# 1165          MWI        Malawi  2011                                     9.9
# 1166          MCO        Monaco  2011                                     NaN
# 1167          SMR    San Marino  2011                                     NaN
# 1168          SSD   South Sudan  2011                                     NaN
# 1169          SDN         Sudan  2011                                     NaN
#
# [1170 rows x 4 columns]

# %%
# impoting GDP per capita dataset

gdp = pd.read_csv('/content/3. GDP per capita (Constant 2015 US).csv')
gdp
# Out:
#                                     Country Name Country Code  Year  \
# 0                                    Afghanistan          AFG  2016
# 1                                        Albania          ALB  2016
# 2                                        Algeria          DZA  2016
# 3                                 American Samoa          ASM  2016
# 4                                        Andorra          AND  2016
# ...                                          ...          ...   ...
# 1591                          Sub-Saharan Africa          SSF  2011
# 1592  Sub-Saharan Africa (excluding high income)          SSA  2011
# 1593   Sub-Saharan Africa (IDA & IBRD countries)          TSS  2011
# 1594                         Upper middle income          UMC  2011
# 1595                                       World          WLD  2011
#
#       GDP per capita
# 0         590.427367
# 1        4090.372739
# 2        4246.242160
# 3       13116.430980
# 4       39886.640090
# ...              ...
# 1591     1611.063696
# 1592     1609.859997
# 1593     1611.063696
# 1594     6488.353978
# 1595     9503.641584
#
# [1596 rows x 4 columns]

# %%
# importing govt. health expenditure dataset

hexp = pd.read_csv('/content/4. Domestic general government health expenditure ( of GDP).csv')
hexp
# Out:
#                                     Country Name Country Code  Year  \
# 0                                    Afghanistan          AFG  2016
# 1                                        Albania          ALB  2016
# 2                                        Algeria          DZA  2016
# 3                                 American Samoa          ASM  2016
# 4                                        Andorra          AND  2016
# ...                                          ...          ...   ...
# 1591                          Sub-Saharan Africa          SSF  2011
# 1592  Sub-Saharan Africa (excluding high income)          SSA  2011
# 1593   Sub-Saharan Africa (IDA & IBRD countries)          TSS  2011
# 1594                         Upper middle income          UMC  2011
# 1595                                       World          WLD  2011
#
#       Govt. Health Expenditure
# 0                     0.600130
# 1                     2.803707
# 2                     4.472452
# 3                          NaN
# 4                     5.070960
# ...                        ...
# 1591                  1.915322
# 1592                  1.914608
# 1593                  1.915322
# 1594                  2.826103
# 1595                  5.691549
#
# [1596 rows x 4 columns]

# %%
# impoting maternal mortality ratio dataset

mmr = pd.read_csv('/content/5. Maternal Mortality Ratio.csv')
mmr
# Out:
#                                     Country Name Country Code  Year  \
# 0                                    Afghanistan          AFG  2016
# 1                                        Albania          ALB  2016
# 2                                        Algeria          DZA  2016
# 3                                 American Samoa          ASM  2016
# 4                                        Andorra          AND  2016
# ...                                          ...          ...   ...
# 1591                          Sub-Saharan Africa          SSF  2011
# 1592  Sub-Saharan Africa (excluding high income)          SSA  2011
# 1593   Sub-Saharan Africa (IDA & IBRD countries)          TSS  2011
# 1594                         Upper middle income          UMC  2011
# 1595                                       World          WLD  2011
#
#       Maternal Mortality Ratio
# 0                        750.0
# 1                          7.0
# 2                         89.0
# 3                          NaN
# 4                          NaN
# ...                        ...
# 1591                     633.0
# 1592                     622.0
# 1593                     622.0
# 1594                      71.0
# 1595                     247.0
#
# [1596 rows x 4 columns]

# %%
# importing mean age at first birth dataset

mafb = pd.read_csv('/content/6. Mean-age-at-first-birth-of-women-aged-20-50-data.csv')
mafb
# Out:
#     Country Name     Continent Country Code  Year  \
# 0    Afghanistan  Asia/Pacific          AFG  2016
# 1        Albania        Europe          ALB  2016
# 2        Algeria        Africa          DZA  2016
# 3         Angola        Africa          AGO  2016
# 4        Armenia        Europe          ARM  2016
# ..           ...           ...          ...   ...
# 685      Vanuatu  Asia/Pacific          VUT  2011
# 686      Vietnam  Asia/Pacific          VNM  2011
# 687        Yemen  Asia/Pacific          YEM  2011
# 688       Zambia        Africa          ZMB  2011
# 689     Zimbabwe        Africa          ZWE  2011
#
#      Mean age of women at first birth
# 0                                19.5
# 1                                22.8
# 2                                24.5
# 3                                19.1
# 4                                21.9
# ..                                ...
# 685                               NaN
# 686                              22.6
# 687                              19.5
# 688                              18.8
# 689                              19.7
#
# [690 rows x 5 columns]

# %%
# Since we already have 'Continent' in the first data frame, dropping the column

mafb = mafb.drop(columns = 'Continent')
mafb
# Out:
#     Country Name Country Code  Year  Mean age of women at first birth
# 0    Afghanistan          AFG  2016                              19.5
# 1        Albania          ALB  2016                              22.8
# 2        Algeria          DZA  2016                              24.5
# 3         Angola          AGO  2016                              19.1
# 4        Armenia          ARM  2016                              21.9
# ..           ...          ...   ...                               ...
# 685      Vanuatu          VUT  2011                               NaN
# 686      Vietnam          VNM  2011                              22.6
# 687        Yemen          YEM  2011                              19.5
# 688       Zambia          ZMB  2011                              18.8
# 689     Zimbabwe          ZWE  2011                              19.7
#
# [690 rows x 4 columns]

# %%
# importing school enrollment by female dataset

edu = pd.read_csv('/content/7. School enrollment secondary female ( gross).csv')
edu
# Out:
#                                     Country Name Country Code  Year  \
# 0                                    Afghanistan          AFG  2016
# 1                                        Albania          ALB  2016
# 2                                        Algeria          DZA  2016
# 3                                 American Samoa          ASM  2016
# 4                                        Andorra          AND  2016
# ...                                          ...          ...   ...
# 1591                          Sub-Saharan Africa          SSF  2011
# 1592  Sub-Saharan Africa (excluding high income)          SSA  2011
# 1593   Sub-Saharan Africa (IDA & IBRD countries)          TSS  2011
# 1594                         Upper middle income          UMC  2011
# 1595                                       World          WLD  2011
#
#       School enrollment rate, secondary, female
# 0                                     37.302528
# 1                                     94.238571
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 1591                                  36.936218
# 1592                                  36.933281
# 1593                                  36.936218
# 1594                                  90.074448
# 1595                                  71.138290
#
# [1596 rows x 4 columns]

# %%
# Since we will be merging all of these dataframes, dropping the overlapping column, 'Country Name' from all of these dataframes except for the first one

specific_dataframes = [malw, gdp, hexp, mmr, mafb, edu]
column_to_drop = 'Country Name'

for i in specific_dataframes:
    if column_to_drop in i.columns:
        i.drop(column_to_drop, axis = 1, inplace = True)

# %%
# Merging on 'Country Code' and then 'Year'

df = mal.merge(malw, on = ['Country Code', 'Year']).merge(gdp, on = ['Country Code', 'Year']).merge(hexp, on = ['Country Code', 'Year']).merge(mmr, on = ['Country Code', 'Year']).merge(mafb, on = ['Country Code', 'Year']).merge(edu, on = ['Country Code', 'Year'])
df
# Out:
#     Country Name     Continent Country Code  Year  \
# 0        Albania        Europe          ALB  2016
# 1        Algeria        Africa          DZA  2016
# 2         Angola        Africa          AGO  2016
# 3        Armenia        Europe          ARM  2016
# 4     Azerbaijan        Europe          AZE  2016
# ..           ...           ...          ...   ...
# 631      Vanuatu  Asia/Pacific          VUT  2011
# 632      Vietnam  Asia/Pacific          VNM  2011
# 633        Yemen  Asia/Pacific          YEM  2011
# 634       Zambia        Africa          ZMB  2011
# 635     Zimbabwe        Africa          ZWE  2011
#
#      Percentage of Underweight Children  \
# 0                                  2.05
# 1                                  4.09
# 2                                 19.10
# 3                                  2.60
# 4                                   NaN
# ..                                  ...
# 631                                 NaN
# 632                               11.70
# 633                               39.60
# 634                               14.50
# 635                                9.70
#
#      Prevelance of Underweight among Adults  GDP per capita  \
# 0                                       2.2     4090.372739
# 1                                       3.6     4246.242160
# 2                                      10.9     2914.412131
# 3                                       3.5     3689.830085
# 4                                       3.2     5270.739099
# ..                                      ...             ...
# 631                                     2.8     2768.747027
# 632                                    20.3     2135.782152
# 633                                     9.0     2159.845146
# 634                                     9.6     1222.979058
# 635                                     5.3     1239.241793
#
#      Govt. Health Expenditure  Maternal Mortality Ratio  \
# 0                    2.803707                       7.0
# 1                    4.472452                      89.0
# 2                    1.197537                     270.0
# 3                    1.637343                      24.0
# 4                    1.163398                      26.0
# ..                        ...                       ...
# 631                  2.360593                      95.0
# 632                  1.784869                      90.0
# 633                  1.092118                     155.0
# 634                  1.203880                     233.0
# 635                  2.119954                     562.0
#
#      Mean age of women at first birth  \
# 0                                22.8
# 1                                24.5
# 2                                19.1
# 3                                21.9
# 4                                 NaN
# ..                                ...
# 631                               NaN
# 632                              22.6
# 633                              19.5
# 634                              18.8
# 635                              19.7
#
#      School enrollment rate, secondary, female
# 0                                    94.238571
# 1                                          NaN
# 2                                    39.741829
# 3                                          NaN
# 4                                          NaN
# ..                                         ...
# 631                                        NaN
# 632                                        NaN
# 633                                  35.637112
# 634                                        NaN
# 635                                        NaN
#
# [636 rows x 11 columns]

# %%
# Renaming the columns for convenience

df.rename(columns = {"Percentage of Underweight Children" : "Child Underweight",
                    "Prevelance of Underweight among Adults" : "Women Underweight",
                    "Maternal Mortality Ratio" : "MMR",
                    "Mean age of women at first birth" : "Mother's age",
                    "School enrollment rate, secondary, female" : "Female Education"}, inplace = True)
df
# Out:
#     Country Name     Continent Country Code  Year  Child Underweight  \
# 0        Albania        Europe          ALB  2016               2.05
# 1        Algeria        Africa          DZA  2016               4.09
# 2         Angola        Africa          AGO  2016              19.10
# 3        Armenia        Europe          ARM  2016               2.60
# 4     Azerbaijan        Europe          AZE  2016                NaN
# ..           ...           ...          ...   ...                ...
# 631      Vanuatu  Asia/Pacific          VUT  2011                NaN
# 632      Vietnam  Asia/Pacific          VNM  2011              11.70
# 633        Yemen  Asia/Pacific          YEM  2011              39.60
# 634       Zambia        Africa          ZMB  2011              14.50
# 635     Zimbabwe        Africa          ZWE  2011               9.70
#
#      Women Underweight  GDP per capita  Govt. Health Expenditure    MMR  \
# 0                  2.2     4090.372739                  2.803707    7.0
# 1                  3.6     4246.242160                  4.472452   89.0
# 2                 10.9     2914.412131                  1.197537  270.0
# 3                  3.5     3689.830085                  1.637343   24.0
# 4                  3.2     5270.739099                  1.163398   26.0
# ..                 ...             ...                       ...    ...
# 631                2.8     2768.747027                  2.360593   95.0
# 632               20.3     2135.782152                  1.784869   90.0
# 633                9.0     2159.845146                  1.092118  155.0
# 634                9.6     1222.979058                  1.203880  233.0
# 635                5.3     1239.241793                  2.119954  562.0
#
#      Mother's age  Female Education
# 0            22.8         94.238571
# 1            24.5               NaN
# 2            19.1         39.741829
# 3            21.9               NaN
# 4             NaN               NaN
# ..            ...               ...
# 631           NaN               NaN
# 632          22.6               NaN
# 633          19.5         35.637112
# 634          18.8               NaN
# 635          19.7               NaN
#
# [636 rows x 11 columns]

# %%
#specific_continents = ['Asia/Pacific', 'Africa']
#dfa = df[df['Continent'].isin(specific_continents)]
#dfa

# %%
# Resetting the index

df.reset_index(inplace = True)
df
# Out:
#      index Country Name     Continent Country Code  Year  Child Underweight  \
# 0        0      Albania        Europe          ALB  2016               2.05
# 1        1      Algeria        Africa          DZA  2016               4.09
# 2        2       Angola        Africa          AGO  2016              19.10
# 3        3      Armenia        Europe          ARM  2016               2.60
# 4        4   Azerbaijan        Europe          AZE  2016                NaN
# ..     ...          ...           ...          ...   ...                ...
# 631    631      Vanuatu  Asia/Pacific          VUT  2011                NaN
# 632    632      Vietnam  Asia/Pacific          VNM  2011              11.70
# 633    633        Yemen  Asia/Pacific          YEM  2011              39.60
# 634    634       Zambia        Africa          ZMB  2011              14.50
# 635    635     Zimbabwe        Africa          ZWE  2011               9.70
#
#      Women Underweight  GDP per capita  Govt. Health Expenditure    MMR  \
# 0                  2.2     4090.372739                  2.803707    7.0
# 1                  3.6     4246.242160                  4.472452   89.0
# 2                 10.9     2914.412131                  1.197537  270.0
# 3                  3.5     3689.830085                  1.637343   24.0
# 4                  3.2     5270.739099                  1.163398   26.0
# ..                 ...             ...                       ...    ...
# 631                2.8     2768.747027                  2.360593   95.0
# 632               20.3     2135.782152                  1.784869   90.0
# 633                9.0     2159.845146                  1.092118  155.0
# 634                9.6     1222.979058                  1.203880  233.0
# 635                5.3     1239.241793                  2.119954  562.0
#
#      Mother's age  Female Education
# 0            22.8         94.238571
# 1            24.5               NaN
# 2            19.1         39.741829
# 3            21.9               NaN
# 4             NaN               NaN
# ..            ...               ...
# 631           NaN               NaN
# 632          22.6               NaN
# 633          19.5         35.637112
# 634          18.8               NaN
# 635          19.7               NaN
#
# [636 rows x 12 columns]

# %%
# dropping the additional 'index' column

df = df.drop(columns = 'index')
df
# Out:
#     Country Name     Continent Country Code  Year  Child Underweight  \
# 0        Albania        Europe          ALB  2016               2.05
# 1        Algeria        Africa          DZA  2016               4.09
# 2         Angola        Africa          AGO  2016              19.10
# 3        Armenia        Europe          ARM  2016               2.60
# 4     Azerbaijan        Europe          AZE  2016                NaN
# ..           ...           ...          ...   ...                ...
# 631      Vanuatu  Asia/Pacific          VUT  2011                NaN
# 632      Vietnam  Asia/Pacific          VNM  2011              11.70
# 633        Yemen  Asia/Pacific          YEM  2011              39.60
# 634       Zambia        Africa          ZMB  2011              14.50
# 635     Zimbabwe        Africa          ZWE  2011               9.70
#
#      Women Underweight  GDP per capita  Govt. Health Expenditure    MMR  \
# 0                  2.2     4090.372739                  2.803707    7.0
# 1                  3.6     4246.242160                  4.472452   89.0
# 2                 10.9     2914.412131                  1.197537  270.0
# 3                  3.5     3689.830085                  1.637343   24.0
# 4                  3.2     5270.739099                  1.163398   26.0
# ..                 ...             ...                       ...    ...
# 631                2.8     2768.747027                  2.360593   95.0
# 632               20.3     2135.782152                  1.784869   90.0
# 633                9.0     2159.845146                  1.092118  155.0
# 634                9.6     1222.979058                  1.203880  233.0
# 635                5.3     1239.241793                  2.119954  562.0
#
#      Mother's age  Female Education
# 0            22.8         94.238571
# 1            24.5               NaN
# 2            19.1         39.741829
# 3            21.9               NaN
# 4             NaN               NaN
# ..            ...               ...
# 631           NaN               NaN
# 632          22.6               NaN
# 633          19.5         35.637112
# 634          18.8               NaN
# 635          19.7               NaN
#
# [636 rows x 11 columns]

# %%
import pandas as pd

# Assuming your DataFrame is called 'dfa'
# Check for missing values in Child Underweight
print(df['Child Underweight'].isnull().sum())

# Print DataFrame before grouping (optional)
# print(dfa)  # Uncomment to see the data before grouping

# Group by country, calculate mean child underweight, sort descending,
# and select the top 10
most_underweight = df.groupby('Country Name')['Child Underweight'].mean().sort_values(ascending=False).head(10)

# Print the result
print(most_underweight)
# Out:
# 143
# Country Name
# Timor Leste    41.983333
# Yemen          39.600000
# India          37.900000
# Niger          37.180000
# Bangladesh     32.783333
# Sudan          32.333333
# Chad           29.683333
# Madagascar     29.366667
# Pakistan       28.966667
# Burundi        28.900000
# Name: Child Underweight, dtype: float64

# %%
most_underweight_df = most_underweight.to_frame().reset_index()
print(most_underweight_df)
# Out:
#   Country Name  Child Underweight
# 0  Timor Leste          41.983333
# 1        Yemen          39.600000
# 2        India          37.900000
# 3        Niger          37.180000
# 4   Bangladesh          32.783333
# 5        Sudan          32.333333
# 6         Chad          29.683333
# 7   Madagascar          29.366667
# 8     Pakistan          28.966667
# 9      Burundi          28.900000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming most_underweight_df is your DataFrame

plt.figure(figsize=(6, 4))
palette = ['aqua' if country == 'India' else 'gray' for country in most_underweight_df['Country Name']]
sns.barplot(x='Child Underweight', y='Country Name', data=most_underweight_df, orient='h', palette=palette)
plt.xlabel('Percentage of Underweight Children')
plt.ylabel('Country')
plt.title('Top 10 Countries by Child Underweight')
plt.show()

# %%
# First five rows of the dataset

df.head()
# Out:
#   Country Name Continent Country Code  Year  Child Underweight  \
# 0      Albania    Europe          ALB  2016               2.05
# 1      Algeria    Africa          DZA  2016               4.09
# 2       Angola    Africa          AGO  2016              19.10
# 3      Armenia    Europe          ARM  2016               2.60
# 4   Azerbaijan    Europe          AZE  2016                NaN
#
#    Women Underweight  GDP per capita  Govt. Health Expenditure    MMR  \
# 0                2.2     4090.372739                  2.803707    7.0
# 1                3.6     4246.242160                  4.472452   89.0
# 2               10.9     2914.412131                  1.197537  270.0
# 3                3.5     3689.830085                  1.637343   24.0
# 4                3.2     5270.739099                  1.163398   26.0
#
#    Mother's age  Female Education
# 0          22.8         94.238571
# 1          24.5               NaN
# 2          19.1         39.741829
# 3          21.9               NaN
# 4           NaN               NaN

# %%
# Information about the dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Country Name              636 non-null    object
#  1   Continent                 636 non-null    object
#  2   Country Code              636 non-null    object
#  3   Year                      636 non-null    int64
#  4   Child Underweight         493 non-null    float64
#  5   Women Underweight         624 non-null    float64
#  6   GDP per capita            625 non-null    float64
#  7   Govt. Health Expenditure  619 non-null    float64
#  8   MMR                       630 non-null    float64
#  9   Mother's age              508 non-null    float64
#  10  Female Education          413 non-null    float64
# dtypes: float64(7), int64(1), object(3)
# memory usage: 54.8+ KB

# %%
# Dropping duplicates if any

df.drop_duplicates()
# Out:
#     Country Name     Continent Country Code  Year  Child Underweight  \
# 0        Albania        Europe          ALB  2016               2.05
# 1        Algeria        Africa          DZA  2016               4.09
# 2         Angola        Africa          AGO  2016              19.10
# 3        Armenia        Europe          ARM  2016               2.60
# 4     Azerbaijan        Europe          AZE  2016                NaN
# ..           ...           ...          ...   ...                ...
# 631      Vanuatu  Asia/Pacific          VUT  2011                NaN
# 632      Vietnam  Asia/Pacific          VNM  2011              11.70
# 633        Yemen  Asia/Pacific          YEM  2011              39.60
# 634       Zambia        Africa          ZMB  2011              14.50
# 635     Zimbabwe        Africa          ZWE  2011               9.70
#
#      Women Underweight  GDP per capita  Govt. Health Expenditure    MMR  \
# 0                  2.2     4090.372739                  2.803707    7.0
# 1                  3.6     4246.242160                  4.472452   89.0
# 2                 10.9     2914.412131                  1.197537  270.0
# 3                  3.5     3689.830085                  1.637343   24.0
# 4                  3.2     5270.739099                  1.163398   26.0
# ..                 ...             ...                       ...    ...
# 631                2.8     2768.747027                  2.360593   95.0
# 632               20.3     2135.782152                  1.784869   90.0
# 633                9.0     2159.845146                  1.092118  155.0
# 634                9.6     1222.979058                  1.203880  233.0
# 635                5.3     1239.241793                  2.119954  562.0
#
#      Mother's age  Female Education
# 0            22.8         94.238571
# 1            24.5               NaN
# 2            19.1         39.741829
# 3            21.9               NaN
# 4             NaN               NaN
# ..            ...               ...
# 631           NaN               NaN
# 632          22.6               NaN
# 633          19.5         35.637112
# 634          18.8               NaN
# 635          19.7               NaN
#
# [636 rows x 11 columns]

# %%
# Null value percentage in the each column

df.isnull().sum()/468 * 100
# Out:
# Country Name                 0.000000
# Continent                    0.000000
# Country Code                 0.000000
# Year                         0.000000
# Child Underweight           30.555556
# Women Underweight            2.564103
# GDP per capita               2.350427
# Govt. Health Expenditure     3.632479
# MMR                          1.282051
# Mother's age                27.350427
# Female Education            47.649573
# dtype: float64

# %%
numerical_cols = ['Child Underweight', 'Women Underweight', 'GDP per capita', 'Govt. Health Expenditure', 'MMR', "Mother's age", 'Female Education']
country_avg_subset = df.groupby('Country Name')[numerical_cols].mean()

# %%
# Seperating out country and continent

dsep = df[['Country Name', 'Continent', 'Country Code', 'Year']]
dsep
# Out:
#     Country Name     Continent Country Code  Year
# 0        Albania        Europe          ALB  2016
# 1        Algeria        Africa          DZA  2016
# 2         Angola        Africa          AGO  2016
# 3        Armenia        Europe          ARM  2016
# 4     Azerbaijan        Europe          AZE  2016
# ..           ...           ...          ...   ...
# 631      Vanuatu  Asia/Pacific          VUT  2011
# 632      Vietnam  Asia/Pacific          VNM  2011
# 633        Yemen  Asia/Pacific          YEM  2011
# 634       Zambia        Africa          ZMB  2011
# 635     Zimbabwe        Africa          ZWE  2011
#
# [636 rows x 4 columns]

# %%
df.drop(columns = ['Continent', 'Country Code'], inplace = True)

# %%
# Replacing the null values with the country average
for column in numerical_cols:
    df[column].fillna(country_avg_subset[column], inplace=True)

df.reset_index(inplace=True)
df
# Out:
#      index Country Name  Year  Child Underweight  Women Underweight  \
# 0        0      Albania  2016               2.05                2.2
# 1        1      Algeria  2016               4.09                3.6
# 2        2       Angola  2016              19.10               10.9
# 3        3      Armenia  2016               2.60                3.5
# 4        4   Azerbaijan  2016                NaN                3.2
# ..     ...          ...   ...                ...                ...
# 631    631      Vanuatu  2011                NaN                2.8
# 632    632      Vietnam  2011              11.70               20.3
# 633    633        Yemen  2011              39.60                9.0
# 634    634       Zambia  2011              14.50                9.6
# 635    635     Zimbabwe  2011               9.70                5.3
#
#      GDP per capita  Govt. Health Expenditure    MMR  Mother's age  \
# 0       4090.372739                  2.803707    7.0          22.8
# 1       4246.242160                  4.472452   89.0          24.5
# 2       2914.412131                  1.197537  270.0          19.1
# 3       3689.830085                  1.637343   24.0          21.9
# 4       5270.739099                  1.163398   26.0           NaN
# ..              ...                       ...    ...           ...
# 631     2768.747027                  2.360593   95.0           NaN
# 632     2135.782152                  1.784869   90.0          22.6
# 633     2159.845146                  1.092118  155.0          19.5
# 634     1222.979058                  1.203880  233.0          18.8
# 635     1239.241793                  2.119954  562.0          19.7
#
#      Female Education
# 0           94.238571
# 1                 NaN
# 2           39.741829
# 3                 NaN
# 4                 NaN
# ..                ...
# 631               NaN
# 632               NaN
# 633         35.637112
# 634               NaN
# 635               NaN
#
# [636 rows x 10 columns]

# %%
# adding back the 'Continent', 'Country Code' columns in dfa

df = dsep.merge(df, on = ['Country Name', 'Year'], how = 'inner')
df
# Out:
#     Country Name     Continent Country Code  Year  index  Child Underweight  \
# 0        Albania        Europe          ALB  2016      0               2.05
# 1        Algeria        Africa          DZA  2016      1               4.09
# 2         Angola        Africa          AGO  2016      2              19.10
# 3        Armenia        Europe          ARM  2016      3               2.60
# 4     Azerbaijan        Europe          AZE  2016      4                NaN
# ..           ...           ...          ...   ...    ...                ...
# 631      Vanuatu  Asia/Pacific          VUT  2011    631                NaN
# 632      Vietnam  Asia/Pacific          VNM  2011    632              11.70
# 633        Yemen  Asia/Pacific          YEM  2011    633              39.60
# 634       Zambia        Africa          ZMB  2011    634              14.50
# 635     Zimbabwe        Africa          ZWE  2011    635               9.70
#
#      Women Underweight  GDP per capita  Govt. Health Expenditure    MMR  \
# 0                  2.2     4090.372739                  2.803707    7.0
# 1                  3.6     4246.242160                  4.472452   89.0
# 2                 10.9     2914.412131                  1.197537  270.0
# 3                  3.5     3689.830085                  1.637343   24.0
# 4                  3.2     5270.739099                  1.163398   26.0
# ..                 ...             ...                       ...    ...
# 631                2.8     2768.747027                  2.360593   95.0
# 632               20.3     2135.782152                  1.784869   90.0
# 633                9.0     2159.845146                  1.092118  155.0
# 634                9.6     1222.979058                  1.203880  233.0
# 635                5.3     1239.241793                  2.119954  562.0
#
#      Mother's age  Female Education
# 0            22.8         94.238571
# 1            24.5               NaN
# 2            19.1         39.741829
# 3            21.9               NaN
# 4             NaN               NaN
# ..            ...               ...
# 631           NaN               NaN
# 632          22.6               NaN
# 633          19.5         35.637112
# 634          18.8               NaN
# 635          19.7               NaN
#
# [636 rows x 12 columns]

# %%
# Checking if there still null values left

df.isnull().sum()/468 * 100
# Out:
# Country Name                 0.000000
# Continent                    0.000000
# Country Code                 0.000000
# Year                         0.000000
# index                        0.000000
# Child Underweight           30.555556
# Women Underweight            2.564103
# GDP per capita               2.350427
# Govt. Health Expenditure     3.632479
# MMR                          1.282051
# Mother's age                27.350427
# Female Education            47.649573
# dtype: float64

# %%
# Save the merged DataFrame as a CSV file
# Replace 'merged_dataset.csv' with the desired file name
df.to_csv('merged_datasett2.csv', index=False)
df
# Out:
#     Country Name     Continent Country Code  Year  index  Child Underweight  \
# 0        Albania        Europe          ALB  2016      0               2.05
# 1        Algeria        Africa          DZA  2016      1               4.09
# 2         Angola        Africa          AGO  2016      2              19.10
# 3        Armenia        Europe          ARM  2016      3               2.60
# 4     Azerbaijan        Europe          AZE  2016      4                NaN
# ..           ...           ...          ...   ...    ...                ...
# 631      Vanuatu  Asia/Pacific          VUT  2011    631                NaN
# 632      Vietnam  Asia/Pacific          VNM  2011    632              11.70
# 633        Yemen  Asia/Pacific          YEM  2011    633              39.60
# 634       Zambia        Africa          ZMB  2011    634              14.50
# 635     Zimbabwe        Africa          ZWE  2011    635               9.70
#
#      Women Underweight  GDP per capita  Govt. Health Expenditure    MMR  \
# 0                  2.2     4090.372739                  2.803707    7.0
# 1                  3.6     4246.242160                  4.472452   89.0
# 2                 10.9     2914.412131                  1.197537  270.0
# 3                  3.5     3689.830085                  1.637343   24.0
# 4                  3.2     5270.739099                  1.163398   26.0
# ..                 ...             ...                       ...    ...
# 631                2.8     2768.747027                  2.360593   95.0
# 632               20.3     2135.782152                  1.784869   90.0
# 633                9.0     2159.845146                  1.092118  155.0
# 634                9.6     1222.979058                  1.203880  233.0
# 635                5.3     1239.241793                  2.119954  562.0
#
#      Mother's age  Female Education
# 0            22.8         94.238571
# 1            24.5               NaN
# 2            19.1         39.741829
# 3            21.9               NaN
# 4             NaN               NaN
# ..            ...               ...
# 631           NaN               NaN
# 632          22.6               NaN
# 633          19.5         35.637112
# 634          18.8               NaN
# 635          19.7               NaN
#
# [636 rows x 12 columns]

# %%
df.dropna(inplace = True)

# %%
# Save the merged DataFrame as a CSV file
# Replace 'merged_dataset.csv' with the desired file name
df.to_csv('merged_datasett.csv', index=False)
df
# Out:
#     Country Name     Continent Country Code  Year  index  Child Underweight  \
# 0        Albania        Europe          ALB  2016      0               2.05
# 2         Angola        Africa          AGO  2016      2              19.10
# 5     Bangladesh  Asia/Pacific          BGD  2016      5              28.50
# 9          Benin        Africa          BEN  2016      9              19.10
# 14       Burundi        Africa          BDI  2016     14              29.10
# ..           ...           ...          ...   ...    ...                ...
# 620     Thailand  Asia/Pacific          THA  2011    620               8.83
# 621  Timor Leste  Asia/Pacific          TLS  2011    621              43.20
# 626       Turkey  Asia/Pacific          TUR  2011    626               2.08
# 629       Uganda        Africa          UGA  2011    629              14.00
# 633        Yemen  Asia/Pacific          YEM  2011    633              39.60
#
#      Women Underweight  GDP per capita  Govt. Health Expenditure    MMR  \
# 0                  2.2     4090.372739                  2.803707    7.0
# 2                 10.9     2914.412131                  1.197537  270.0
# 5                 23.0     1307.732333                  0.569685  196.0
# 9                  8.6     1045.150937                  0.574913  590.0
# 14                11.2      282.975967                  2.345776  508.0
# ..                 ...             ...                       ...    ...
# 620                9.5     5091.958066                  2.727069   34.0
# 621               19.4     1234.275594                  3.568223  358.0
# 626                1.9     9207.513495                  3.681827   23.0
# 629               11.2      817.958451                  0.908633  359.0
# 633                9.0     2159.845146                  1.092118  155.0
#
#      Mother's age  Female Education
# 0            22.8         94.238571
# 2            19.1         39.741829
# 5            18.4         75.010811
# 9            20.0         50.731831
# 14           20.7         47.356010
# ..            ...               ...
# 620          22.5         88.118073
# 621          21.5         65.967903
# 626          21.7         84.496590
# 629          18.3         23.766609
# 633          19.5         35.637112
#
# [312 rows x 12 columns]

# %%
# Creating boxplots to show outliers in each numerical column

def boxplot(col):
    sns.boxplot(df[col], color = 'aqua')
    plt.title(col)
    plt.show()

for i in list(df.select_dtypes(exclude = ['object']).columns)[0:]:
    boxplot(i)

# %%
print(df.dtypes)
# Out:
# Country Name                 object
# Continent                    object
# Country Code                 object
# Year                          int64
# index                         int64
# Child Underweight           float64
# Women Underweight           float64
# GDP per capita              float64
# Govt. Health Expenditure    float64
# MMR                         float64
# Mother's age                float64
# Female Education            float64
# dtype: object

# %%
numerical_cols = ['Year', 'Child Underweight', 'Women Underweight', 'GDP per capita',
                  'Govt. Health Expenditure', 'MMR', "Mother's age", 'Female Education']

Q1 = df[numerical_cols].quantile(0.25)
Q3 = df[numerical_cols].quantile(0.75)
IQR = Q3 - Q1

up = Q3 + IQR * 1.5
down = Q1 - IQR * 1.5

print(up)
print('-----')
print(down)
# Out:
# Year                        2019.500000
# Child Underweight             54.050000
# Women Underweight             23.550000
# GDP per capita              9862.240673
# Govt. Health Expenditure       5.879179
# MMR                         1159.000000
# Mother's age                  24.500000
# Female Education             163.279545
# dtype: float64
# -----
# Year                        2007.500000
# Child Underweight            -26.350000
# Women Underweight             -8.850000
# GDP per capita             -4600.014850
# Govt. Health Expenditure      -2.060668
# MMR                         -611.000000
# Mother's age                  16.500000
# Female Education             -39.170071
# dtype: float64

# %%
# Drop the 'index' column
df.drop('index', axis=1, inplace=True)

# Save the modified DataFrame as a CSV file
df.to_csv('merged_dataset.csv', index=False)
df
# Out:
#     Country Name     Continent Country Code  Year  Child Underweight  \
# 0        Albania        Europe          ALB  2016               2.05
# 2         Angola        Africa          AGO  2016              19.10
# 5     Bangladesh  Asia/Pacific          BGD  2016              28.50
# 9          Benin        Africa          BEN  2016              19.10
# 14       Burundi        Africa          BDI  2016              29.10
# ..           ...           ...          ...   ...                ...
# 620     Thailand  Asia/Pacific          THA  2011               8.83
# 621  Timor Leste  Asia/Pacific          TLS  2011              43.20
# 626       Turkey  Asia/Pacific          TUR  2011               2.08
# 629       Uganda        Africa          UGA  2011              14.00
# 633        Yemen  Asia/Pacific          YEM  2011              39.60
#
#      Women Underweight  GDP per capita  Govt. Health Expenditure    MMR  \
# 0                  2.2     4090.372739                  2.803707    7.0
# 2                 10.9     2914.412131                  1.197537  270.0
# 5                 23.0     1307.732333                  0.569685  196.0
# 9                  8.6     1045.150937                  0.574913  590.0
# 14                11.2      282.975967                  2.345776  508.0
# ..                 ...             ...                       ...    ...
# 620                9.5     5091.958066                  2.727069   34.0
# 621               19.4     1234.275594                  3.568223  358.0
# 626                1.9     9207.513495                  3.681827   23.0
# 629               11.2      817.958451                  0.908633  359.0
# 633                9.0     2159.845146                  1.092118  155.0
#
#      Mother's age  Female Education
# 0            22.8         94.238571
# 2            19.1         39.741829
# 5            18.4         75.010811
# 9            20.0         50.731831
# 14           20.7         47.356010
# ..            ...               ...
# 620          22.5         88.118073
# 621          21.5         65.967903
# 626          21.7         84.496590
# 629          18.3         23.766609
# 633          19.5         35.637112
#
# [312 rows x 11 columns]

# %% [markdown]
# # ***CAREFULLLL***

# %%
specific_continents = ['Asia/Pacific', 'Africa']
dfa = df[df['Continent'].isin(specific_continents)]
dfa
# Out:
#     Country Name     Continent Country Code  Year  Child Underweight  \
# 2         Angola        Africa          AGO  2016              19.10
# 5     Bangladesh  Asia/Pacific          BGD  2016              28.50
# 9          Benin        Africa          BEN  2016              19.10
# 14       Burundi        Africa          BDI  2016              29.10
# 16      Cameroon        Africa          CMR  2016              12.30
# ..           ...           ...          ...   ...                ...
# 620     Thailand  Asia/Pacific          THA  2011               8.83
# 621  Timor Leste  Asia/Pacific          TLS  2011              43.20
# 626       Turkey  Asia/Pacific          TUR  2011               2.08
# 629       Uganda        Africa          UGA  2011              14.00
# 633        Yemen  Asia/Pacific          YEM  2011              39.60
#
#      Women Underweight  GDP per capita  Govt. Health Expenditure    MMR  \
# 2                 10.9     2914.412131                  1.197537  270.0
# 5                 23.0     1307.732333                  0.569685  196.0
# 9                  8.6     1045.150937                  0.574913  590.0
# 14                11.2      282.975967                  2.345776  508.0
# 16                 6.3     1420.029872                  0.365931  437.0
# ..                 ...             ...                       ...    ...
# 620                9.5     5091.958066                  2.727069   34.0
# 621               19.4     1234.275594                  3.568223  358.0
# 626                1.9     9207.513495                  3.681827   23.0
# 629               11.2      817.958451                  0.908633  359.0
# 633                9.0     2159.845146                  1.092118  155.0
#
#      Mother's age  Female Education
# 2            19.1         39.741829
# 5            18.4         75.010811
# 9            20.0         50.731831
# 14           20.7         47.356010
# 16           19.4         55.443081
# ..            ...               ...
# 620          22.5         88.118073
# 621          21.5         65.967903
# 626          21.7         84.496590
# 629          18.3         23.766609
# 633          19.5         35.637112
#
# [229 rows x 11 columns]

# %%
# Select numerical columns for groupby operation
numerical_cols = ['Child Underweight', 'Women Underweight', 'GDP per capita',
                  'Govt. Health Expenditure', 'MMR', "Mother's age", 'Female Education']

# Filter the DataFrame for desired continents
filter_dfa = dfa[dfa['Continent'].isin(['Asia/Pacific', 'Africa'])]

# Group by Continent and Year, then calculate the mean of numerical columns
avg = filter_dfa.groupby(['Continent', 'Year'])[numerical_cols].mean()

# Display the result
avg
# Out:
#                    Child Underweight  Women Underweight  GDP per capita  \
# Continent    Year
# Africa       2011          20.000000          10.266667     1048.295402
#              2012          18.658400          10.136000     1162.102120
#              2013          17.621481           9.211111     1381.133011
#              2014          17.402222           9.233333     1379.297980
#              2015          17.985000           9.366667     1338.716187
#              2016          15.318333           8.333333     1678.817839
# Asia/Pacific 2011          20.994286          11.942857     3006.267402
#              2012          20.644286          11.714286     3106.345921
#              2013          20.066429          11.471429     3213.149287
#              2014          17.849091          11.263636     3643.579737
#              2015          20.055000          12.870000     3663.125661
#              2016          17.889167          11.758333     3583.893510
#
#                    Govt. Health Expenditure         MMR  Mother's age  \
# Continent    Year
# Africa       2011                  1.420412  579.074074     19.411111
#              2012                  1.435499  542.200000     19.492000
#              2013                  1.517494  494.740741     19.633333
#              2014                  1.514128  483.481481     19.692593
#              2015                  1.606097  509.875000     19.662500
#              2016                  1.772759  454.291667     20.070833
# Asia/Pacific 2011                  2.069918  148.357143     20.864286
#              2012                  2.169265  137.500000     20.928571
#              2013                  2.115707  129.785714     20.978571
#              2014                  2.170536  136.363636     21.572727
#              2015                  1.884026  137.100000     21.130000
#              2016                  1.907530  131.000000     21.383333
#
#                    Female Education
# Continent    Year
# Africa       2011         35.882447
#              2012         39.012385
#              2013         45.043725
#              2014         45.736836
#              2015         45.582732
#              2016         50.071915
# Asia/Pacific 2011         67.299167
#              2012         68.759365
#              2013         71.261321
#              2014         77.196532
#              2015         80.734881
#              2016         82.719501

# %%
avg.reset_index(inplace = True)

# %%
# Creating line plot for Child Underweight

plt.figure(figsize = (6,4))
sns.lineplot(data = avg, x = 'Year', y = 'Child Underweight', hue = 'Continent')
plt.title('Child Malnutrition: Asia vs Africa')
plt.xlabel('Year')
plt.ylabel('Percentage of Underweight Children')
plt.show()

# %%
# Creating line plot for GDP per capita

plt.figure(figsize = (6,4))
sns.lineplot(data = avg, x = 'Year', y = 'GDP per capita', hue = 'Continent')
plt.title('GDP per capita: Asia vs Africa')
plt.xlabel('Year')
plt.ylabel('GDP per capita (Constant 2015 USD)')
plt.show()

# %%
# Values for India

Ind = dfa[dfa['Country Name'].str.contains('India')]
Ind
# Out:
#     Country Name     Continent Country Code  Year  Child Underweight  \
# 44         India  Asia/Pacific          IND  2016               36.1
# 150        India  Asia/Pacific          IND  2015               36.8
# 256        India  Asia/Pacific          IND  2014               37.5
# 362        India  Asia/Pacific          IND  2013               38.3
# 468        India  Asia/Pacific          IND  2012               39.0
# 574        India  Asia/Pacific          IND  2011               39.7
#
#      Women Underweight  GDP per capita  Govt. Health Expenditure    MMR  \
# 44                24.2     1701.184227                  0.940500  121.0
# 150               24.5     1590.174322                  0.921932  128.0
# 256               24.9     1490.028499                  0.856535  135.0
# 362               25.2     1404.545338                  0.865042  154.0
# 468               25.6     1337.476103                  0.931869  162.0
# 574               26.0     1285.283027                  0.937319  170.0
#
#      Mother's age  Female Education
# 44           20.4         76.038948
# 150          20.3         74.685295
# 256          20.1         75.039261
# 362          20.0         69.481766
# 468          19.9         67.636864
# 574          19.8         64.669250

# %%
# Line plot for Child Underweight

plt.figure(figsize = (6,4))
sns.lineplot(data = Ind, x = 'Year', y = 'Child Underweight')
plt.title('Child Malnutrition: India')
plt.xlabel('Year')
plt.ylabel('Percentage of Underweight Children')
plt.show()

# %%
# Line plot for GDP per capita

plt.figure(figsize = (6,4))
sns.lineplot(data = Ind, x = 'Year', y = 'GDP per capita')
plt.title('GDP per capita: India')
plt.xlabel('Year')
plt.ylabel('GDP per capita (Constant 2015 USD)')
plt.show()

# %%
# Scatterplot between different variables

sns.pairplot(dfa)
plt.show()

# %%
# Scatter plot between Child Underweight and Women Underweight

plt.figure(figsize = (6,4))
sns.scatterplot(data = dfa, x = 'Women Underweight', y = 'Child Underweight')
plt.title('Women Underweight vs Child Underweight')
plt.xlabel('Percentage of Underweight Women')
plt.ylabel('Percentage of Underweight Children')
plt.show()

# %%
# Distribution of the variables

def distplot(col):
    plt.figure(figsize = (6,4))
    sns.distplot(dfa[col], color = 'aqua')
    plt.show()

for i in list(dfa.select_dtypes(exclude = ['object']).columns)[0:]:
    distplot(i)

# %%
# Select numerical columns for correlation calculation
numerical_cols = ['Child Underweight', 'Women Underweight', 'GDP per capita',
                  'Govt. Health Expenditure', 'MMR', "Mother's age", 'Female Education']

# Calculate the correlation matrix
corr = dfa[numerical_cols].corr()

# Plot the heatmap
plt.figure(figsize=(20, 15))
sns.heatmap(corr, cmap='Greens', annot=True)
plt.show()

# %% [markdown]
# Model 1: OLS Regression (with Constant)

# %%
dfb = dfa.copy()
dfb
# Out:
#     Country Name     Continent Country Code  Year  Child Underweight  \
# 2         Angola        Africa          AGO  2016              19.10
# 5     Bangladesh  Asia/Pacific          BGD  2016              28.50
# 9          Benin        Africa          BEN  2016              19.10
# 14       Burundi        Africa          BDI  2016              29.10
# 16      Cameroon        Africa          CMR  2016              12.30
# ..           ...           ...          ...   ...                ...
# 620     Thailand  Asia/Pacific          THA  2011               8.83
# 621  Timor Leste  Asia/Pacific          TLS  2011              43.20
# 626       Turkey  Asia/Pacific          TUR  2011               2.08
# 629       Uganda        Africa          UGA  2011              14.00
# 633        Yemen  Asia/Pacific          YEM  2011              39.60
#
#      Women Underweight  GDP per capita  Govt. Health Expenditure    MMR  \
# 2                 10.9     2914.412131                  1.197537  270.0
# 5                 23.0     1307.732333                  0.569685  196.0
# 9                  8.6     1045.150937                  0.574913  590.0
# 14                11.2      282.975967                  2.345776  508.0
# 16                 6.3     1420.029872                  0.365931  437.0
# ..                 ...             ...                       ...    ...
# 620                9.5     5091.958066                  2.727069   34.0
# 621               19.4     1234.275594                  3.568223  358.0
# 626                1.9     9207.513495                  3.681827   23.0
# 629               11.2      817.958451                  0.908633  359.0
# 633                9.0     2159.845146                  1.092118  155.0
#
#      Mother's age  Female Education
# 2            19.1         39.741829
# 5            18.4         75.010811
# 9            20.0         50.731831
# 14           20.7         47.356010
# 16           19.4         55.443081
# ..            ...               ...
# 620          22.5         88.118073
# 621          21.5         65.967903
# 626          21.7         84.496590
# 629          18.3         23.766609
# 633          19.5         35.637112
#
# [229 rows x 11 columns]

# %%
dfb
# Out:
#     Country Name     Continent Country Code  Year  Child Underweight  \
# 2         Angola        Africa          AGO  2016              19.10
# 5     Bangladesh  Asia/Pacific          BGD  2016              28.50
# 9          Benin        Africa          BEN  2016              19.10
# 14       Burundi        Africa          BDI  2016              29.10
# 16      Cameroon        Africa          CMR  2016              12.30
# ..           ...           ...          ...   ...                ...
# 620     Thailand  Asia/Pacific          THA  2011               8.83
# 621  Timor Leste  Asia/Pacific          TLS  2011              43.20
# 626       Turkey  Asia/Pacific          TUR  2011               2.08
# 629       Uganda        Africa          UGA  2011              14.00
# 633        Yemen  Asia/Pacific          YEM  2011              39.60
#
#      Women Underweight  GDP per capita  Govt. Health Expenditure    MMR  \
# 2                 10.9     2914.412131                  1.197537  270.0
# 5                 23.0     1307.732333                  0.569685  196.0
# 9                  8.6     1045.150937                  0.574913  590.0
# 14                11.2      282.975967                  2.345776  508.0
# 16                 6.3     1420.029872                  0.365931  437.0
# ..                 ...             ...                       ...    ...
# 620                9.5     5091.958066                  2.727069   34.0
# 621               19.4     1234.275594                  3.568223  358.0
# 626                1.9     9207.513495                  3.681827   23.0
# 629               11.2      817.958451                  0.908633  359.0
# 633                9.0     2159.845146                  1.092118  155.0
#
#      Mother's age  Female Education
# 2            19.1         39.741829
# 5            18.4         75.010811
# 9            20.0         50.731831
# 14           20.7         47.356010
# 16           19.4         55.443081
# ..            ...               ...
# 620          22.5         88.118073
# 621          21.5         65.967903
# 626          21.7         84.496590
# 629          18.3         23.766609
# 633          19.5         35.637112
#
# [229 rows x 11 columns]

# %%
# Dividing the dataframe into dependent and independent variables

# Dependent Variable
y = dfb['Child Underweight']

# Independent Variable
x = dfb[['Women Underweight', 'GDP per capita', 'Govt. Health Expenditure', 'MMR', "Mother's age", 'Female Education']]

# %%
# OLS Regression

import statsmodels.api as sm
x1 = sm.add_constant(x)
result = sm.OLS(y,x1).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      Child Underweight   R-squared:                       0.761
# Model:                            OLS   Adj. R-squared:                  0.755
# Method:                 Least Squares   F-statistic:                     117.9
# Date:                Sun, 12 May 2024   Prob (F-statistic):           3.40e-66
# Time:                        13:15:18   Log-Likelihood:                -706.50
# No. Observations:                 229   AIC:                             1427.
# Df Residuals:                     222   BIC:                             1451.
# Df Model:                           6
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                      -23.8458      8.454     -2.821      0.005     -40.506      -7.185
# Women Underweight            1.6308      0.082     19.912      0.000       1.469       1.792
# GDP per capita               0.0002      0.000      0.728      0.467      -0.000       0.001
# Govt. Health Expenditure     0.3011      0.386      0.780      0.436      -0.459       1.062
# MMR                          0.0072      0.002      4.122      0.000       0.004       0.011
# Mother's age                 1.3780      0.418      3.300      0.001       0.555       2.201
# Female Education            -0.1073      0.026     -4.206      0.000      -0.158      -0.057
# ==============================================================================
# Omnibus:                       80.934   Durbin-Watson:                   2.180
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              265.717
# Skew:                           1.478   Prob(JB):                     2.00e-58
# Kurtosis:                       7.372   Cond. No.                     7.29e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.29e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# Model 2: OLS Regression (without Constant)

# %%
result2 = sm.OLS(y,x).fit()
result2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:      Child Underweight   R-squared (uncentered):                   0.937
# Model:                            OLS   Adj. R-squared (uncentered):              0.935
# Method:                 Least Squares   F-statistic:                              549.6
# Date:                Sun, 12 May 2024   Prob (F-statistic):                   1.38e-130
# Time:                        13:15:18   Log-Likelihood:                         -710.53
# No. Observations:                 229   AIC:                                      1433.
# Df Residuals:                     223   BIC:                                      1454.
# Df Model:                           6
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Women Underweight            1.5706      0.080     19.561      0.000       1.412       1.729
# GDP per capita               0.0002      0.000      1.054      0.293      -0.000       0.001
# Govt. Health Expenditure     0.5348      0.383      1.397      0.164      -0.219       1.289
# MMR                          0.0048      0.002      3.114      0.002       0.002       0.008
# Mother's age                 0.2301      0.095      2.420      0.016       0.043       0.417
# Female Education            -0.1022      0.026     -3.955      0.000      -0.153      -0.051
# ==============================================================================
# Omnibus:                       66.109   Durbin-Watson:                   2.169
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              159.746
# Skew:                           1.319   Prob(JB):                     2.05e-35
# Kurtosis:                       6.128   Cond. No.                     3.26e+03
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 3.26e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# Model 3

# %%
# Dependent Variable
y = dfb['Child Underweight']

# Independent Variable
x2 = dfb[['Women Underweight', 'MMR', "Mother's age", 'Female Education']]

# %%
result3 = sm.OLS(y,x2).fit()
result3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:      Child Underweight   R-squared (uncentered):                   0.936
# Model:                            OLS   Adj. R-squared (uncentered):              0.935
# Method:                 Least Squares   F-statistic:                              821.2
# Date:                Sun, 12 May 2024   Prob (F-statistic):                   6.36e-133
# Time:                        13:15:18   Log-Likelihood:                         -711.90
# No. Observations:                 229   AIC:                                      1432.
# Df Residuals:                     225   BIC:                                      1446.
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Women Underweight     1.5059      0.069     21.689      0.000       1.369       1.643
# MMR                   0.0050      0.002      3.220      0.001       0.002       0.008
# Mother's age          0.2650      0.093      2.857      0.005       0.082       0.448
# Female Education     -0.0775      0.021     -3.759      0.000      -0.118      -0.037
# ==============================================================================
# Omnibus:                       69.127   Durbin-Watson:                   2.159
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              171.860
# Skew:                           1.368   Prob(JB):                     4.80e-38
# Kurtosis:                       6.245   Cond. No.                         141.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
